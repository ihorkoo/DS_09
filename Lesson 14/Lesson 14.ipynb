# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 6: Data visualization

# %% [markdown]
# #### Мета:
#
# * навчитися візуалізовувати дані в Python

# %% [markdown]
# Matplotlib - це бібліотека візуалізації даних за допомогою Python. Її створив Джон Хантер, щоб спробувати відтворити можливості побудови графіків MatLab (іншої мови програмування) в Python.
# Отже, якщо ви знайомі з matlab, matplotlib буде для вас дуже зрозумілою.
#
# Це крута бібліотека для побудови 2D та 3D графіків.
#
# Документація: http://matplotlib.org/
#
# ## Встановлення
#
# Для встановлення matplotlib:
#
#     conda install matplotlib
# або
#
#     pip install matplotlib
#
# ## Імпортування

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
# Цей рядок призначений лише для блокнотів jupyter.
# Якщо ви використовуєте інший редактор, то використовуйте: plt.show () 
# в кінці всіх ваших команд побудови графіка, щоб фігура появлялась в іншому вікні.

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# #### Основні команди Matplotlib

# %%
plt.plot(x, y, 'b')

plt.xlabel('X')
plt.ylabel('Y')

plt.title('First')
# Out:
# Text(0.5, 1.0, 'First')

# %% [markdown]
# #### Декілька кординатних площин на одному полотні

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'g-*') 


plt.subplot(1,2,2)
plt.plot(y, x, 'r-')

# %% [markdown]
# #### Обєктно-орієнтовний підхід

# %% [markdown]
# Об'єкт plt.subplots () працює як автоматичний менеджер осей.

# %%
fig, axes = plt.subplots(nrows=2, ncols=3)

# %%
axes[0][1]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
plt.tight_layout()

# %%
help(plt.tight_layout)
# Out:
# Help on function tight_layout in module matplotlib.pyplot:
#
# tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)
#     Automatically adjust subplot parameters to give specified padding.
#
#     Parameters
#     ----------
#     pad : float
#         Padding between the figure edge and the edges of subplots,
#         as a fraction of the font size.
#     h_pad, w_pad : float, optional
#         Padding (height/width) between edges of adjacent subplots,
#         as a fraction of the font size.  Defaults to *pad*.
#     rect : tuple (left, bottom, right, top), optional
#         A rectangle (left, bottom, right, top) in the normalized
#         figure coordinate that the whole subplots area (including
#         labels) will fit into. Default is (0, 0, 1, 1).

# %%
fig, ax = plt.subplots(2, 2)


ax[0][0].plot(x, x**2)


ax[1][1].plot(x, x**(1/2))

ax[0][1].plot(x, y, 'r')

plt.tight_layout()

# %%
ax

# %% [markdown]
# #### Легенда, заголовок, мітки даних

# %%
fig, ax = plt.subplots()

ax.set_title("Заголовок");
ax.set_xlabel("x")
ax.set_ylabel("y")

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.plot(x, x**4, label="x**4")

ax.legend(loc=3) #параметр loc визначає розміщення легенди

# %% [markdown]
# #### Розмір полотна

# %%
# fig = plt.figure(figsize=(8,1), dpi=100)
fig, axes = plt.subplots(figsize=(4,4))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Заголовок');

# %% [markdown]
# #### Відображення ліній осей

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3))


axes[0].plot(x, x**2, x, x**3, lw=1)
axes[0].grid(True)


axes[1].plot(x, x**2, x, x**3)
axes[1].grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# #### Види графіків

# %% [markdown]
# 1. Scatter

# %%
plt.scatter(x,y)

# %% [markdown]
# 2. Гістограма

# %%
len(data)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([12.,  5., 10., 11., 12.,  8., 10., 13.,  7., 12.]),
#  array([  5. , 104.2, 203.4, 302.6, 401.8, 501. , 600.2, 699.4, 798.6,
#         897.8, 997. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# 3. Коробчастий графік

# %%
data
# Out:
# [array([-0.11734405, -1.64372353,  0.58884428,  2.86157953,  0.25010367,
#          1.81373051, -0.28383952, -0.15859981,  1.07838366,  0.37213856]),
#  array([ 4.39111641,  0.2444878 ,  0.37300904,  2.32090101, -1.72461482,
#         -1.12147216,  0.04055353, -2.56311367,  2.27075051, -2.2167256 ]),
#  array([ 0.54367731,  2.49213145, -2.05778723,  1.5075789 ,  3.54521999,
#         -3.01609628, -3.28553114, -0.00903202,  3.79097277,  1.0068613 ])]

# %%
data = [np.random.normal(0, std, 10) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ff7db5e5c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ff7dbb74c8>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1ff7daadd48>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1ff7db1f5c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1ff7dbb3bc8>,
# ...
#  'means': []}

# %% [markdown]
# 4. Стовбчикова діаграма

# %%
fig, axes = plt.subplots()

axes.bar(x, x**2, align="center", width=0.1, alpha=0.5)
axes.set_title("Стовбчикова діаграма")
# Out:
# Text(0.5, 1.0, 'Стовбчикова діаграма')

# %% [markdown]
# 5. Крокова діаграма

# %%
fig, axes = plt.subplots()
axes.step(x, x**2, lw=1)
axes.set_title("Крокова діаграма")
# Out:
# Text(0.5, 1.0, 'Крокова діаграма')

# %% [markdown]
# 6. Діаграма криволінійної фігури

# %%
fig, axes = plt.subplots()
axes.fill_between(x, x**2, x**3);
axes.set_title("Діаграма криволінійної фігури");

# %% [markdown]
# #### Збереження графіків
# Є можливість зберігати графіки у різних форматах:  PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("img.png", dpi=200)

# %% [markdown]
# ### Seaborn

# %%
from IPython import display
display.Image("https://seaborn.pydata.org/_images/function_overview_8_0.png")

# %%
import seaborn as sns

# %%
import pandas as pd
salaries = pd.read_csv('Salaries.csv')
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# Seaborn — це крта бібліотека візуалізації даних для побудови статистичної графіки на Python. Надає красиві стилі за замовчуванням і палітри кольорів, щоб статистичні графіки були більш привабливими. Побудований на основі бібліотеки matplotlib, а також тісно інтегрований зі структурами даних від pandas.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']
# C:\Users\i.betlei\Anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\i.betlei\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)

# %% [markdown]
# Seaborn підтримує різні теми, які можуть полегшити оформлення сюжетів і заощадити багато часу. Використовуючи функцію set_style() Seaborn, ми можемо встановити будь-яку з тем, доступних у бібліотеці Seaborn. Ось кілька популярних тем:
#
# - Darkgrid
# - Whitegrid
# - Dark
# - White
# - Ticks

# %%
sns.set_style("dark")

# %%
sns.palplot(sns.color_palette("PiYG", 10))

# %%
sns.palplot(sns.color_palette("GnBu", 10))

# %%
sns.palplot(sns.color_palette("dark", 10))

# %% [markdown]
# ### Histogram

# %%
sns.distplot(salaries['TotalPay'],kde = False)

# %%
sum(salaries['TotalPay'] > 200_000)
# Out:
# 2008

# %%
salaries.shape
# Out:
# (148654, 13)

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(x = 'Year', y = 'TotalPayBenefits', data = salaries,
            palette = 'PuRd',ci=None 
            )
plt.show()

# %%
sns.barplot(x = 'Year', y = 'TotalPayBenefits', hue = 'Agency', data = salaries,
            palette = 'PuRd' 
            )
plt.legend()

# %% [markdown]
# ### Point Plot

# %%
sns.pointplot(x="Year", y="TotalPay", data=salaries)

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='TotalPay', y='Benefits',data=salaries)

# %%
sns.jointplot(x='TotalPay', y='Benefits',data=salaries,  kind='reg')

# %%
sns.jointplot(x='TotalPay', y='Benefits',data=salaries,  kind='kde')

# %%
sns.jointplot(x='TotalPay', y='Benefits',data=salaries,  kind='hex')

# %%
sns.regplot(x="TotalPay", y="Benefits", data=salaries)

# %% [markdown]
# ### Lm Plot

# %%
sns.lmplot(x="TotalPay", y="Benefits", col="Year",
               data=salaries)

# %% [markdown]
# ### KDE plot

# %% [markdown]
# Kernel Density Estimate
# В статистиці, я́дрова оці́нка густини́ розпо́ділу  — це непараметричний метод оцінки функції густини випадкової величини за вибіркою. Ядрова оцінка густини є важливою задачею згладжування даних; при застосуванні методу судження щодо статистичних властивостей популяції здійснюється на базі скінченної вибірки.

# %%
sns.kdeplot(salaries[salaries['Year']==2013]['TotalPay'], color='b', shade=True, label='2013') 
sns.kdeplot(salaries[salaries['Year']==2012]['TotalPay'], color='r', shade=True, label='2012')

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x="Year", y="TotalPay", data=salaries)

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x=salaries["TotalPay"])

# %%
salaries.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204878    -0.081505 -0.100403 -0.348957
# BasePay          -0.204878  1.000000     0.266740  0.285655  0.918028
# OvertimePay      -0.081505  0.266740     1.000000  0.316592  0.301207
# OtherPay         -0.100403  0.285655     0.316592  1.000000  0.233178
# Benefits         -0.348957  0.918028     0.301207  0.233178  1.000000
# TotalPay         -0.211478  0.954494     0.504859  0.470496  0.884097
# TotalPayBenefits -0.092190  0.946595     0.467981  0.422341  0.930140
# Year              0.968171  0.033751     0.027887 -0.002499 -0.043136
# Notes                  NaN       NaN          NaN       NaN       NaN
# Status                 NaN       NaN          NaN       NaN       NaN
#
#                   TotalPay  TotalPayBenefits      Year  Notes  Status
# Id               -0.211478         -0.092190  0.968171    NaN     NaN
# ...

# %% [markdown]
# ### Heatmap

# %%
corr=salaries.corr()
sns.heatmap(corr,annot=True,linewidths=1.5,cmap="YlGnBu")

# %% [markdown]
# ### Facetgrid

# %%
g = sns.FacetGrid(salaries, col="Year")
g.map(sns.scatterplot, "TotalPay", "Benefits")

# %% [markdown]
# ----

# %%
salaries['JobTitle'] = salaries.JobTitle.str.lower() 

top_ten_occupations = salaries.JobTitle.value_counts().sort_values(ascending=False).head(10).index
top_ten_occupations
# Out:
# Index(['transit operator', 'special nurse', 'registered nurse', 'custodian',
#        'firefighter', 'recreation leader', 'deputy sheriff',
#        'public svc aide-public works', 'police officer 3',
#        'patient care assistant'],
#       dtype='object')

# %%
salaries_averages_by_occupation = (salaries[salaries.JobTitle.isin(top_ten_occupations)]
                                   .groupby('JobTitle')[['BasePay', 'Benefits', 'OvertimePay']]
                                   .aggregate('mean')
)

ax = salaries_averages_by_occupation.plot(kind='barh', figsize=(8,8))

ax.set_xlabel('Mean Pay')
# Out:
# Text(0.5, 0, 'Mean Pay')

# %%
salary_percents = salaries_averages_by_occupation.div(salaries_averages_by_occupation.sum(1), 
                                                      axis=0)
  
ax = salary_percents.plot(kind='bar', stacked=True)

# %%
salaries['LastNameLength'] = (salaries
                              .EmployeeName
                              .str.split()
                              .apply(lambda a: len(a[-1]))
                              )

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
salaries.LastNameLength.hist(bins=20, ax=ax, alpha=.3)
